# %% [markdown]
# <a href="https://colab.research.google.com/github/gopalasthana24/aps-gopal/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra_extended(graph, start):
    distances = {node: float('inf') for node in graph}
    predecessors = {node: None for node in graph}
    visited = []
    distances[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')
        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                predecessors[neighbor] = min_node

    return distances, predecessors

def reconstruct_path(predecessors, start, end):
    path = []
    current = end
    while current is not None:
        path.insert(0, current)
        current = predecessors[current]
    return path if path[0] == start else []


def get_user_graph():
    graph = {}
    n = int(input("Enter number of edges: "))
    print("Enter edges as 'Source Destination Weight' (e.g., A B 5):")
    for _ in range(n):
        u, v, w = input().split()
        w = int(w)
        if u not in graph: graph[u] = {}
        if v not in graph: graph[v] = {}
        graph[u][v] = w
        graph[v][u] = w
    return graph

example_graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 5, 'D': 10},
    'C': {'A': 2, 'B': 5, 'D': 3, 'E': 8},
    'D': {'B': 10, 'C': 3, 'F': 6},
    'E': {'C': 8, 'F': 2},
    'F': {'D': 6, 'E': 2}
}

def test_algorithm(graph, source_node):
    print(f"\n--- Results for Source Node: {source_node} ---")
    distances, preds = dijkstra_extended(graph, source_node)

    for target in graph:
        path = reconstruct_path(preds, source_node, target)
        path_str = " -> ".join(path)
        print(f"Target {target}: Distance = {distances[target]}, Path = [{path_str}]")

test_algorithm(example_graph, 'A')
test_algorithm(example_graph, 'F')
# Out:
# --- Results for Source Node: A ---
# Target A: Distance = 0, Path = [A]
# Target B: Distance = 4, Path = [A -> B]
# Target C: Distance = 2, Path = [A -> C]
# Target D: Distance = 5, Path = [A -> C -> D]
# Target E: Distance = 10, Path = [A -> C -> E]
# Target F: Distance = 11, Path = [A -> C -> D -> F]
#
# --- Results for Source Node: F ---
# Target A: Distance = 11, Path = [F -> D -> C -> A]
# Target B: Distance = 14, Path = [F -> D -> C -> B]
# Target C: Distance = 9, Path = [F -> D -> C]
# Target D: Distance = 6, Path = [F -> D]
# Target E: Distance = 2, Path = [F -> E]
# Target F: Distance = 0, Path = [F]
